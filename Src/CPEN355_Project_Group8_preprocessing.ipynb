# %% [markdown]
# This notebook should include all of the code relevant for preprocessing - including:
# * Code to download the dataset
# * Code the extracts .set files from the LSF system
# * Code that extracts the .set to ndarrays float32 type using EEGLAB
# * Code that checks every .set and extracts the relevant 3 second intervals after the onset of every motion
# * Puts every data set into the relevant place in a data structure.
# * "Ultimately save the data structure in CSV filed under the "Data" Directory
#
# ** Remember - data in the colab environment does not persist, so if you save data structres of files locally, they will be lost. The only way to manage this is to save files to the google drive - start doing with this the first cell below that mounts the google drive and navigates to this repo.
#
# If you want to push/pull - go to the workflow notebook in the root of the repository - it include clear instructions. If needed feel free to as me on the discord.
#
# I have supplied some skeleton code for you to work with @KenMcalister

# %% [markdown]
# This cell mount the google drive and routes the CLI to the current ~/src/. directory where this notebook lives

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/GitRepo/EEG_CNN_CPEN355/src/.
