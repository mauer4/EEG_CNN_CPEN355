# %% [markdown]
# Process to push pull
# - Make sure you have a shortcut of our 'GitRepo' (named 'GitRepo') in the root of your drive, under /MyDrive/GitRepo/.
# - Create /root/.ssh/ directory
# - Mount google drive
# - Copy from our GitRepo the id_colab_rsa (and pub) to the colab environment
# - Push/Pull
#
# How to use files in the directory:
# - Mount google drive
# - Make sure you have a shortcut name 'GitRepo' to our 'GitRepo' under your 'MyDrive/GitRepo/.'
# - Use Path /content/drive/MyDrive/GitRepo/. as base path to that directory

# %% [markdown]
# Run the next cell if you want to do do any git operations that require ssh authentication

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p ~/.ssh
# !cp ~/.ssh/id_colab_rsa /content/drive/MyDrive/GitRepo/.
# !cp ~/.ssh/id_colab_rsa.pub /content/drive/MyDrive/GitRepo/.
#!mkdir -p /root/.ssh
# !echo -e "Host github.com\n\tStrictHostKeyChecking no\n\tUser github\n\tIdentityFile /root/.ssh/id_colab_rsa\n" > /root/.ssh/config
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Check if the files are in /root/.ssh/ for Github access

# %%
# !ls /root/.ssh/
# Out:
# config	id_colab_rsa  id_colab_rsa.pub

# %% [markdown]
# Run this cell to navigate to this directory

# %%
# %cd /content/drive/MyDrive/GitRepo/EEG_CNN_CPEN355/.
# !git config --global user.email "mauer4@gmail.com"
# !git config --global user.name "Adin Mauer"
# Out:
# /content/drive/MyDrive/CPEN 355/GitRepo/EEG_CNN_CPEN355

# %% [markdown]
# Run the next cell to push repo

# %%
# !git push git@github.com:mauer4/EEG_CNN_CPEN355.git
# Out:
# Everything up-to-date

# %% [markdown]
# run the next cell to pull repo changes

# %%
# !git pull git@github.com:mauer4/EEG_CNN_CPEN355.git

# %%
# %pwd
# !git add .
# !git commit -m "Added workflow notebook to repo"
# Out:
# [main 5fbab77] Added workflow notebook to repo
#  1 file changed, 1 insertion(+)
#  create mode 100644 CPEN355_Project_Group8_workflow.ipynb
